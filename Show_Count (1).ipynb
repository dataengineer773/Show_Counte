# %%
def show_count(count, name):
    print(count, name)

# %%
show_count(1983, 'SHAN')
# Out:
# 1983 SHAN

# %%
show_count(1362, 'NICK')
# Out:
# 1362 NICK

# %%
show_count(2, 'SHAHROUKH')
# Out:
# 2 SHAHROUKH
